# %%
#from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream

# %%
from TwitterSearch import *
try:
#     tso = TwitterSearchOrder() # create a TwitterSearchOrder object
#     tso.set_keywords(['Guttenberg', 'Doktorarbeit']) # let's define all words we would like to have a look for
#     tso.set_language('de') # we want to see German tweets only
#     tso.set_include_entities(False) # and don't give us all those entity information
    tso = TwitterUserOrder('United') # create a TwitterUserOrder


    # it's about time to create a TwitterSearch object with our secret tokens
    ts = TwitterSearch(
        consumer_key = '6fSBGn2EDiJNzl7307OC2Diip',
        consumer_secret = 'eugcz1wbUPJsvJ1pOMIQj9LuvgrXjzMIIGFPRKGjdrThtCwkca',
        access_token = '2168818422-YREGvLaxlNghgfRQa52Z1b20nM3Vq55Fd77nh0T',
        access_token_secret = '6pY9NU8eq6lPgFlgGY11rUQ00BsfjM67cJwXD0gHUa7uy'
     )

     # this is where the fun actually starts :)
    for tweet in ts.search_tweets_iterable(tso):
        print( '@%s tweeted: %s' % ( tweet['user']['screen_name'], tweet['text'] ) )

except TwitterSearchException as e: # take care of all those ugly errors if there are some
    print(e)
# Out:
# @united tweeted: @MontgomeryKen We're delighted to hear it! ^NJ
# @united tweeted: @realsarahpepper Hi, Sarah. Your frustration is heard. Please DM the baggage claim number and we can look for an up… https://t.co/zPzM7etbD7
# @united tweeted: @jennife526 Jennifer, did you receive assistance? ^NJ
# @united tweeted: @arroiz_oficial What is your flight number today? ^NJ
# @united tweeted: @HeltonMN What is your flight number today? ^NJ
# @united tweeted: @TheChrisHags We're disappointed we aren't able to get you on a flight sooner, Christopher. ^NJ
# @united tweeted: @flicarama No problem. ^NJ
# @united tweeted: @dianerocks52 Diane, please let us know if we can assist. ^NJ
# @united tweeted: @flicarama We recommend calling our U.K. number at 0845-607-6760 or 0207-136-0582 for assistance. ^NJ
# @united tweeted: @flicarama At the top of the page is your page reflecting that you are in the U.K.? ^NJ
# ...

# %%
tso = TwitterUserOrder('United')
response = ts.search_tweets_iterable(tso)

# start asking Twitter about the timeline
count =0
for tweet in response: #ts.search_tweets_iterable(tso):
    count +=1
    print('@%s TIME:%s  %s' % (tweet['user']['screen_name'], tweet['created_at'], tweet['user']['followers_count']))
#print len(response['content']['statuses'])
# Out:
# @united TIME:Sat Jul 01 16:53:30 +0000 2017  927507
# @united TIME:Sat Jul 01 16:51:45 +0000 2017  927507
# @united TIME:Sat Jul 01 16:45:32 +0000 2017  927507
# @united TIME:Sat Jul 01 16:38:51 +0000 2017  927507
# @united TIME:Sat Jul 01 16:38:07 +0000 2017  927507
# @united TIME:Sat Jul 01 16:15:59 +0000 2017  927507
# @united TIME:Sat Jul 01 16:15:23 +0000 2017  927507
# @united TIME:Sat Jul 01 16:11:38 +0000 2017  927507
# @united TIME:Sat Jul 01 16:07:24 +0000 2017  927507
# @united TIME:Sat Jul 01 16:06:55 +0000 2017  927507
# @united TIME:Sat Jul 01 16:04:34 +0000 2017  927507
# @united TIME:Sat Jul 01 15:56:53 +0000 2017  927507
# @united TIME:Sat Jul 01 15:55:50 +0000 2017  927507
# @united TIME:Sat Jul 01 15:46:45 +0000 2017  927507
# @united TIME:Sat Jul 01 15:42:55 +0000 2017  927507
# @united TIME:Sat Jul 01 15:38:05 +0000 2017  927507
# @united TIME:Sat Jul 01 15:36:03 +0000 2017  927507
# @united TIME:Sat Jul 01 15:34:18 +0000 2017  927507
# ...

# %%
count
# Out:
# 3226

# %%
tso = TwitterSearchOrder()
tso.set_keywords(['#Nordstrom' ,'-Anniversary sale'])
res_search = ts.search_tweets(tso)
#len(res_search)

# %%
len(res_search['content']['statuses'])
# Out:
# 100

# %%
j =0
for r in res_search['content']['statuses']:
    j += 1
    print ('@%s createdat %s %s' % (r['user']['screen_name'], r['created_at'], r['text'].replace('\n','')))
# Out:
# @ChadMcd13576827 createdat Fri Jun 30 17:35:46 +0000 2017 RT @DangeRussWilson: Any Dog Lovers? @GoodManBrand #Nordstrom Anniversary Sale campaign. #comingsoon #ad https://t.co/lKW72KgAPa
# @NathanJones99 createdat Fri Jun 30 12:47:09 +0000 2017 RT @DangeRussWilson: Excited to share the first images of @GoodManBrand from the #Nordstrom Anniversary Sale campaign. #comingsoon #ad http…
# @musicluvah21 createdat Fri Jun 30 05:58:19 +0000 2017 RT @DangeRussWilson: Excited to share the first images of @GoodManBrand from the #Nordstrom Anniversary Sale campaign. #comingsoon #ad http…
# @AllSassNclass createdat Fri Jun 30 05:56:54 +0000 2017 RT @DangeRussWilson: Excited to share the first images of @GoodManBrand from the #Nordstrom Anniversary Sale campaign. #comingsoon #ad http…
# @clasictrndsettr createdat Fri Jun 30 00:33:07 +0000 2017 The #Nordstrom Anniversary Sale Catalog is live! Check out my blog to see my top… https://t.co/TRpPCbQOqv
# ...

# %%
j
# Out:
# 100

# %%
type(res_search['content'])
# Out:
# list

# %%
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream

# %%
CONSUMER_KEY = '6fSBGn2EDiJNzl7307OC2Diip'
CONSUMER_SECRET = 'eugcz1wbUPJsvJ1pOMIQj9LuvgrXjzMIIGFPRKGjdrThtCwkca'
ACCESS_TOKEN = '2168818422-YREGvLaxlNghgfRQa52Z1b20nM3Vq55Fd77nh0T'
ACCESS_SECRET = '6pY9NU8eq6lPgFlgGY11rUQ00BsfjM67cJwXD0gHUa7uy'
oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# %%
twitter = Twitter(auth=oauth)

# %%
qres = twitter.search.tweets(q='#apple', lang='en', count=1000)

# %%
type(qres)
# Out:
# twitter.api.TwitterDictResponse

# %%
len(qres['statuses'])
# Out:
# 48

# %%
for r in qres['statuses']:
    print ('@%s createdat %s %s' % (r['user']['screen_name'], r['created_at'], r['text'].replace('\n','')))
# Out:
# @alicesttu createdat Sat Jul 01 19:40:07 +0000 2017 #Apple unveils its new smaller iPhone #Apple... #Apple https://t.co/rB2TTaCYd8
# @mydarkstar createdat Sat Jul 01 19:39:59 +0000 2017 RT @dynamic_idea: #idea: #plantany number of apple #trees#seeds#tree price#age#flowers#apples 🍏🍊🍎#apple #price#seedsthx to http…
# @careersingrowth createdat Sat Jul 01 19:39:58 +0000 2017 RT @Dicedotcom: In case you were wondering, the battle between #Qualcomm and #Apple is still lingering on: https://t.co/uYmLh3RnQj via @9to…
# @Ifeanyidiaye createdat Sat Jul 01 19:38:14 +0000 2017 Is it just me or is there something inexplicably appealing about this apple computer? #Apple #Computer https://t.co/vLaNC3yKMN
# @SofiaHalliday createdat Sat Jul 01 19:38:13 +0000 2017 #AppleWatch Apple Watch Series 2 42mm Space Gray Aluminum Black MPO62LL/A https://t.co/Lmi3fpN0MR #Apple #iWatch https://t.co/smFxrVT2PF
# ...

# %%
query = twitter.search.tweets(q = "#apple")

#-----------------------------------------------------------------------
# How long did this query take?
#-----------------------------------------------------------------------
print "Search complete (%.3f seconds)" % (query["search_metadata"]["completed_in"])

#-----------------------------------------------------------------------
# Loop through each of the results, and print its content.
#-----------------------------------------------------------------------
for result in query["statuses"]:
	print "(%s) @%s %s" % (result["created_at"], result["user"]["screen_name"], result["text"])
# Out:
# Search complete (0.034 seconds)
# (Sat Jul 01 19:38:14 +0000 2017) @Ifeanyidiaye Is it just me or is there something inexplicably appealing about this apple computer? #Apple #Computer https://t.co/vLaNC3yKMN
# (Sat Jul 01 19:38:13 +0000 2017) @SofiaHalliday #AppleWatch Apple Watch Series 2 42mm Space Gray Aluminum Black MPO62LL/A https://t.co/Lmi3fpN0MR #Apple #iWatch https://t.co/smFxrVT2PF
# (Sat Jul 01 19:38:01 +0000 2017) @FactUdontIgnore RT @FactUdontIgnore: Did you know❓
# #Facts #DidYouKnow #Apple #Logo #Newton #brands #branding #iPhone #mobile #devices #digital #Fact
# ❤RT ht…
# (Sat Jul 01 19:37:36 +0000 2017) @JamesBoutros In great shape #apple #iphone6
# (Sat Jul 01 19:37:35 +0000 2017) @gramalit RT @SpirosMargaris: #Apple is preparing for the #death of the #iPhone
#
# https://t.co/g8DRWTGdyI #fintech @kifleswing #AI #AR #VC https://t.…
# ...

# %%
CONSUMER_KEY = '6fSBGn2EDiJNzl7307OC2Diip'
CONSUMER_SECRET = 'eugcz1wbUPJsvJ1pOMIQj9LuvgrXjzMIIGFPRKGjdrThtCwkca'
ACCESS_TOKEN = '2168818422-YREGvLaxlNghgfRQa52Z1b20nM3Vq55Fd77nh0T'
ACCESS_SECRET = '6pY9NU8eq6lPgFlgGY11rUQ00BsfjM67cJwXD0gHUa7uy'
oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# %%
import tweepy
# assuming twitter_authentication.py contains each of the 4 oauth elements (1 per line)
#from twitter_authentication import API_KEY, API_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET

# auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
# auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# api = tweepy.API(auth)

auth = tweepy.auth.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

api = tweepy.API(auth)

query = 'python'
max_tweets = 1000

# %%
import sys
import jsonpickle
import os

# %%
query = '#DeleteUber'

searched_tweets = []
last_id = -1
tweetCount = 0
while len(searched_tweets) < max_tweets:
    count = max_tweets - len(searched_tweets)
    try:
        new_tweets = api.search(q=query, count=count, max_id=str(last_id - 1))
        if not new_tweets:
            break
        searched_tweets.extend(new_tweets)
        last_id = new_tweets[-1].id
        if not new_tweets:
            print("No more tweets found")
            break
            
    except tweepy.TweepError as e:
        # depending on TweepError.code, one may want to retry or wait
        # to keep things simple, we will give up on an error
        break

# %%
len(searched_tweets)
# Out:
# 1000

# %%
last_id
# Out:
# 880716896076804097

# %%
type(new_tweets)
# Out:
# tweepy.models.SearchResults

# %%
c =0
for tweet in searched_tweets:
    c += 1
    print ('%s  %s' % (tweet.created_at, tweet.text.replace('\n','')))
# Out:
# 2017-07-01 21:31:00  RT @musgravemum: https://t.co/zvwaPyFQrs UBER passenger paralyzed! #deleteuber @QLDLabor  @QLDLNP
# 2017-07-01 21:30:18  установка гбо на hyundai Santa Fe #deleteuber https://t.co/vg0f8T9E6C
# 2017-07-01 21:04:01  RT @DisruptionHub: Life After Uber https://t.co/5pF6sUxkM2 #disruption #deleteuber #selfdrivingcars #Automotive #AI #leadership #Uber #Lyft
# 2017-07-01 21:01:16  RT @cabbydenny: #ubered #deleteuber (before uber delete you!!) @MayorofLondon 👈🏼clown@ValShawcross 👈🏼invisible@Tanni_GT 👈🏼silent@LondonA…
# 2017-07-01 20:36:29  @jameelajamil @marc_laz Jameela uber are a despicable corrupt organisation with no respect for women public safety… https://t.co/tvsECPxnMA
# 2017-07-01 20:35:52  RT @bcnlimits: @MayoralRafa Hasta que no consigan tener a todos los españoles con salarios de explotación no pararán. #DeleteUber #StopCETA…
# ...

# %%
c
# Out:
# 1000

# %%
c=0
for tweet in tweepy.Cursor(api.search,
                           q="#deleteuber",
                           count=1000,
                           result_type="recent",
                           include_entities=True,
                           lang="en").items():
    print tweet.created_at, tweet.text.replace('\n','')
    c += 1
# Out:
# 2017-07-01 21:31:00 RT @musgravemum: https://t.co/zvwaPyFQrs UBER passenger paralyzed! #deleteuber @QLDLabor  @QLDLNP
# 2017-07-01 21:04:01 RT @DisruptionHub: Life After Uber https://t.co/5pF6sUxkM2 #disruption #deleteuber #selfdrivingcars #Automotive #AI #leadership #Uber #Lyft
# 2017-07-01 21:01:16 RT @cabbydenny: #ubered #deleteuber (before uber delete you!!) @MayorofLondon 👈🏼clown@ValShawcross 👈🏼invisible@Tanni_GT 👈🏼silent@LondonA…
# 2017-07-01 20:36:29 @jameelajamil @marc_laz Jameela uber are a despicable corrupt organisation with no respect for women public safety… https://t.co/tvsECPxnMA
# 2017-07-01 20:33:07 RT @cabbydenny: #ubered #deleteuber (before uber delete you!!) @MayorofLondon 👈🏼clown@ValShawcross 👈🏼invisible@Tanni_GT 👈🏼silent@LondonA…
# 2017-07-01 20:15:23 @beedm88 Are you posting ur East Bay daily commuter routine? U better not ride a Super-Sexist ride to ur work though #DeleteUber
# ...

# %%
c
# Out:
# 1016

# %%
c=0
for tweet in tweepy.Cursor(api.followers,
                           screen_name="united"
                           ).items():
    print ("%s %s %s" %(tweet.created_at, tweet.screen_name, tweet.followers_count))
    c += 1
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-240-6bb6ac55bea4> in <module>()
#       1 c=0
#       2 for tweet in tweepy.Cursor(api.followers,
# ----> 3                            screen_name="united"
#       4                            ).items():
#       5     print ("%s %s %s" %(tweet.created_at, tweet.screen_name, tweet.followers_count))
#
# /opt/conda/lib/python2.7/site-packages/tweepy/cursor.pyc in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /opt/conda/lib/python2.7/site-packages/tweepy/cursor.pyc in next(self)
# ...

# %%
c
# Out:
# 300

# %%
stuff = api.user_timeline(screen_name = 'united', count = 100, include_rts = True)
for status in stuff:
    print status.created_at, status.text, status.user.id, status.user.id_str, status.user.followers_count, status.user.favourites_count
# Out:
#  2017-07-03 01:45:48 @Tattypotamus Hi, thanks for reaching out. Have you filed a claim for your bag? ^CB 260907612 260907612 927703 2210
# 2017-07-03 01:39:11 @PetiteBit She's definitely a beautiful bird! ^CB 260907612 260907612 927703 2210
# 2017-07-03 01:37:59 @cball2013 We understand your frustration, Caleb. To clarify, have you been reunited with your bag? ^KL 260907612 260907612 927703 2210
# 2017-07-03 01:36:35 @PrettyPeets_ Hi, you can do so online at https://t.co/ufFoKFTNNe under My Trips, or by calling into Reservations. ^CB 260907612 260907612 927703 2210
# 2017-07-03 01:35:02 @russrankin Russell, what's going on? ^CB 260907612 260907612 927703 2210
# 2017-07-03 01:27:30 @cmatthewbrooks We're certainly here to listen if you would like to send us more details on what happened, Matt. Yo… https://t.co/vy6Dw73iDS 260907612 260907612 927703 2210
# 2017-07-03 01:21:43 @jmhenry_ Our pleasure. ^NC 260907612 260907612 927703 2210
# ...
